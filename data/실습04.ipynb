# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# %%
n = 10
p = 0.5

num_simul = 1000
successes = np.random.binomial(n, p, num_simul)

# print(successes)
plt.hist(successes, bins=11, range=(0, 10), alpha=0.8)
plt.show()
